# %%
import bilby
import lal
import lalsimulation as lalsim
import numpy as np
import matplotlib.pyplot as plt

bilby.core.utils.setup_logger(outdir=".", label="run_label", log_level="WARNING")
# Define basic parameters for waveform generation
mass_1 = 30  # Mass of the primary black hole in solar masses
mass_2 = 25  # Mass of the secondary black hole in solar masses
luminosity_distance = 400  # Luminosity distance in Mpc
a_1 = 0.6  # Spin magnitude of the primary black hole
a_2 = 0.4  # Spin magnitude of the secondary black hole
tilt_1 = 0.0  # Tilt angle of the primary spin (radians)
tilt_2 = 0.0  # Tilt angle of the secondary spin (radians)
phi_12 = 0.0  # Angle between spin vectors (radians)
phi_jl = 0.0  # Angle between total angular momentum and orbital angular momentum (radians)
theta_jn = 0.4  # Angle between total angular momentum and line of sight (radians)
psi = 2.659  # Polarization angle (radians)
phase = 1.3  # Phase at coalescence (radians)
ra = 1.375  # Right ascension of the source
dec = -1.2108  # Declination of the source
geocent_time = 1126259642.413  # GPS time at coalescence

# Set up waveform arguments
waveform_arguments = {
    "waveform_approximant": "SEOBNRv4PHM",
    "reference_frequency": 50.0,
    "minimum_frequency": 20.0,
}

# Create the waveform generator using bilby's utility function
waveform_generator = bilby.gw.WaveformGenerator(
    duration=4,
    sampling_frequency=2048,
    frequency_domain_source_model=bilby.gw.source.lal_binary_black_hole,
    parameter_conversion=bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters,
    waveform_arguments=waveform_arguments,
)

# Define interferometers (only Hanford in this case)
interferometers = bilby.gw.detector.InterferometerList(["H1"])
interferometers.set_strain_data_from_zero_noise(
    sampling_frequency=2048, duration=4, start_time=geocent_time - 2
)

# Inject a signal into the interferometer data
injection_parameters = dict(
    mass_1=mass_1,
    mass_2=mass_2,
    luminosity_distance=luminosity_distance,
    a_1=a_1,
    a_2=a_2,
    tilt_1=tilt_1,
    tilt_2=tilt_2,
    phi_12=phi_12,
    phi_jl=phi_jl,
    theta_jn=theta_jn,
    psi=psi,
    phase=phase,
    ra=ra,
    dec=dec,
    geocent_time=geocent_time,
)

interferometers.inject_signal(
    waveform_generator=waveform_generator, parameters=injection_parameters
)

# Check the injected signal (plot or analyze as needed)
for ifo in interferometers:
    print(f"Injected signal in {ifo.name}: {ifo.strain_data.time_domain_strain}")
# Out:
# XLAL Error - XLALEOBCheckNyquistFrequency: Ringdown frequency > Nyquist frequency!
# At present this situation is not supported.
# XLAL Error - XLALSimIMRSpinPrecEOBWaveform (LALSimIMRSpinPrecEOBv4P.c:949): Input domain error
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (LALSimInspiralGeneratorLegacy.c:1275): Internal function call failed: Input domain error
# XLAL Error - generate_conditioned_td_waveform_from_td_fallback (LALSimInspiralGeneratorConditioning.c:42): Internal function call failed: Input domain error
# XLAL Error - generate_conditioned_fd_waveform_from_td (LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Input domain error
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 66
#      47 # Inject a signal into the interferometer data
#      48 injection_parameters = dict(
#      49     mass_1=mass_1,
#      50     mass_2=mass_2,
#    (...)
#      63     geocent_time=geocent_time,
#      64 )
# ---> 66 interferometers.inject_signal(
#      67     waveform_generator=waveform_generator, parameters=injection_parameters
#      68 )
#      70 # Check the injected signal (plot or analyze as needed)
#      71 for ifo in interferometers:
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/detector/networks.py:166, in InterferometerList.inject_signal(self, parameters, injection_polarizations, waveform_generator, raise_error)
#     164 if injection_polarizations is None:
#     165     if waveform_generator is not None:
# --> 166         injection_polarizations = waveform_generator.frequency_domain_strain(
#     167             parameters
#     168         )
#     169     else:
#     170         raise ValueError(
#     171             "inject_signal needs one of waveform_generator or "
#     172             "injection_polarizations."
#     173         )
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/waveform_generator.py:131, in WaveformGenerator.frequency_domain_strain(self, parameters)
#     109 def frequency_domain_strain(self, parameters=None):
#     110     """ Wrapper to source_model.
#     111
#     112     Converts self.parameters with self.parameter_conversion before handing it off to the source model.
#    (...)
#     129
#     130     """
# --> 131     return self._calculate_strain(model=self.frequency_domain_source_model,
#     132                                   model_data_points=self.frequency_array,
#     133                                   parameters=parameters,
#     134                                   transformation_function=utils.nfft,
#     135                                   transformed_model=self.time_domain_source_model,
#     136                                   transformed_model_data_points=self.time_array)
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/waveform_generator.py:176, in WaveformGenerator._calculate_strain(self, model, model_data_points, transformation_function, transformed_model, transformed_model_data_points, parameters)
#     174     return self._cache['waveform']
#     175 if model is not None:
# --> 176     model_strain = self._strain_from_model(model_data_points, model)
#     177 elif transformed_model is not None:
#     178     model_strain = self._strain_from_transformed_model(transformed_model_data_points, transformed_model,
#     179                                                        transformation_function)
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/waveform_generator.py:189, in WaveformGenerator._strain_from_model(self, model_data_points, model)
#     188 def _strain_from_model(self, model_data_points, model):
# --> 189     return model(model_data_points, **self.parameters)
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/source.py:325, in lal_binary_black_hole(frequency_array, mass_1, mass_2, luminosity_distance, a_1, tilt_1, phi_12, a_2, tilt_2, phi_jl, theta_jn, phase, **kwargs)
#     319 waveform_kwargs = dict(
#     320     waveform_approximant='IMRPhenomPv2', reference_frequency=50.0,
#     321     minimum_frequency=20.0, maximum_frequency=frequency_array[-1],
#     322     catch_waveform_errors=False, pn_spin_order=-1, pn_tidal_order=-1,
#     323     pn_phase_order=-1, pn_amplitude_order=0)
#     324 waveform_kwargs.update(kwargs)
# --> 325 return _base_lal_cbc_fd_waveform(
#     326     frequency_array=frequency_array, mass_1=mass_1, mass_2=mass_2,
#     327     luminosity_distance=luminosity_distance, theta_jn=theta_jn, phase=phase,
#     328     a_1=a_1, a_2=a_2, tilt_1=tilt_1, tilt_2=tilt_2, phi_12=phi_12,
#     329     phi_jl=phi_jl, **waveform_kwargs)
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/source.py:604, in _base_lal_cbc_fd_waveform(frequency_array, mass_1, mass_2, luminosity_distance, theta_jn, phase, a_1, a_2, tilt_1, tilt_2, phi_12, phi_jl, lambda_1, lambda_2, eccentricity, **waveform_kwargs)
#     602     wf_func = lalsim_SimInspiralFD
#     603 try:
# --> 604     hplus, hcross = wf_func(
#     605         mass_1, mass_2, spin_1x, spin_1y, spin_1z, spin_2x, spin_2y,
#     606         spin_2z, luminosity_distance, iota, phase,
#     607         longitude_ascending_nodes, eccentricity, mean_per_ano, delta_frequency,
#     608         start_frequency, maximum_frequency, reference_frequency,
#     609         waveform_dictionary, approximant)
#     610 except Exception as e:
#     611     if not catch_waveform_errors:
#
# File ~/anaconda3/envs/geotgr/lib/python3.10/site-packages/bilby/gw/utils.py:660, in lalsim_SimInspiralFD(mass_1, mass_2, spin_1x, spin_1y, spin_1z, spin_2x, spin_2y, spin_2z, luminosity_distance, iota, phase, longitude_ascending_nodes, eccentricity, mean_per_ano, delta_frequency, minimum_frequency, maximum_frequency, reference_frequency, waveform_dictionary, approximant)
#     652 args = convert_args_list_to_float(
#     653     mass_1, mass_2, spin_1x, spin_1y, spin_1z, spin_2x, spin_2y, spin_2z,
#     654     luminosity_distance, iota, phase, longitude_ascending_nodes,
#     655     eccentricity, mean_per_ano, delta_frequency, minimum_frequency,
#     656     maximum_frequency, reference_frequency)
#     658 approximant = _get_lalsim_approximant(approximant)
# --> 660 return SimInspiralFD(*args, waveform_dictionary, approximant)
#
# RuntimeError: Internal function call failed: Input domain error

# %%
ifo.strain_data.frequency_domain_strain
# Out:
# array([ 0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j, ...,
#         8.12178765e-30+5.16576872e-30j, -8.17813240e-30-4.91903969e-30j,
#        -2.73086469e-34+1.24914258e-33j])

# %%
dir(ifo.strain_data)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_channel',
#  '_frequency_domain_strain',
#  '_frequency_mask',
#  '_frequency_mask_updated',
#  '_infer_dependence',
#  '_infer_frequency_domain_dependence',
#  '_infer_time_domain_dependence',
#  '_maximum_frequency',
#  '_minimum_frequency',
#  '_notch_list',
#  '_time_domain_strain',
#  '_times_and_frequencies',
#  'alpha',
#  'channel',
#  'create_power_spectral_density',
#  'duration',
#  'frequency_array',
#  'frequency_domain_strain',
#  'frequency_mask',
#  'low_pass_filter',
#  'maximum_frequency',
#  'minimum_frequency',
#  'notch_list',
#  'roll_off',
#  'sampling_frequency',
#  'set_from_channel_name',
#  'set_from_csv',
#  'set_from_frame_file',
#  'set_from_frequency_domain_strain',
#  'set_from_gwpy_timeseries',
#  'set_from_open_data',
#  'set_from_power_spectral_density',
#  'set_from_time_domain_strain',
#  'set_from_zero_noise',
#  'start_time',
#  'time_array',
#  'time_domain_strain',
#  'time_domain_window',
#  'time_within_data',
#  'to_gwpy_frequencyseries',
#  'to_gwpy_timeseries',
#  'to_lal_frequencyseries',
#  'to_lal_timeseries',
#  'to_pycbc_frequencyseries',
#  'to_pycbc_timeseries',
#  'window_factor']

# %%
hf, freqs = waveform_generator.frequency_domain_strain(injection_parameters)

# %%
import lalsimulation
help(lalsimulation)
# Out:
# Help on package lalsimulation:
#
# NAME
#     lalsimulation - # Import SWIG wrappings, if available
#
# PACKAGE CONTENTS
#     _lalsimulation
#     git_version
#     gwsignal (package)
#     lalsimulation
#     nrfits (package)
#     tilts_at_infinity (package)
#
# CLASSES
#     builtins.SwigPyObject(builtins.object)
#         IMRPhenomPv3HMAlphaStruct
#         IMRPhenomPv3HMWignderStruct
#         IMRPhenomPv3HMYlmStruct
#         PNPhasingSeries
#         SimInspiralGenerator
#         SimInspiralSpinTaylorTxCoeffs
#         SimInspiralTestGRParam
#         SimInspiralTestGRParamData
#         SimInspiralWaveformCache
#         SimInspiralWaveformCacheOld
#         SimInspiralWaveformFlags
#         SimNeutronStarEOS
#         SimNeutronStarFamily
#         SphHarmFrequencySeries
#         SphHarmPolarTimeSeries
#         SphHarmTimeSeries
#         swig_lalsimulation_test_parent_map_struct
#         sysq
#         vector
#
#     class IMRPhenomPv3HMAlphaStruct(builtins.SwigPyObject)
#      |  ::tagIMRPhenomPv3HMAlphaStruct
#      |
#      |  Method resolution order:
#      |      IMRPhenomPv3HMAlphaStruct
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(IMRPhenomPv3HMAlphaStruct self) -> IMRPhenomPv3HMAlphaStruct
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(IMRPhenomPv3HMAlphaStruct self, void const * memo) -> IMRPhenomPv3HMAlphaStruct
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      alpha2 : a(5).COMPLEX16
#      |
#      |  alpha2
#      |      alpha2 : a(5).COMPLEX16
#      |
#      |  alpha3
#      |      alpha3 : a(7).COMPLEX16
#      |
#      |  alpha4
#      |      alpha4 : a(9).COMPLEX16
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class IMRPhenomPv3HMWignderStruct(builtins.SwigPyObject)
#      |  ::tagIMRPhenomPv3HMWignderStruct
#      |
#      |  Method resolution order:
#      |      IMRPhenomPv3HMWignderStruct
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(IMRPhenomPv3HMWignderStruct self) -> IMRPhenomPv3HMWignderStruct
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(IMRPhenomPv3HMWignderStruct self, void const * memo) -> IMRPhenomPv3HMWignderStruct
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      XLALSimInspiralSpinTaylorPNEvolveOrbit : int
#      |
#      |  d21
#      |      d21 : a(2).a(5).REAL8
#      |
#      |  d22
#      |      d22 : a(2).a(5).REAL8
#      |
#      |  d32
#      |      d32 : a(2).a(7).REAL8
#      |
#      |  d33
#      |      d33 : a(2).a(7).REAL8
#      |
#      |  d43
#      |      d43 : a(2).a(9).REAL8
#      |
#      |  d44
#      |      d44 : a(2).a(9).REAL8
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class IMRPhenomPv3HMYlmStruct(builtins.SwigPyObject)
#      |  ::tagIMRPhenomPv3HMYlmStruct
#      |
#      |  Method resolution order:
#      |      IMRPhenomPv3HMYlmStruct
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(IMRPhenomPv3HMYlmStruct self) -> IMRPhenomPv3HMYlmStruct
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(IMRPhenomPv3HMYlmStruct self, void const * memo) -> IMRPhenomPv3HMYlmStruct
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  Ylm2
#      |      Ylm2 : a(2).a(5).COMPLEX16
#      |
#      |  Ylm3
#      |      Ylm3 : a(2).a(7).COMPLEX16
#      |
#      |  Ylm4
#      |      Ylm4 : a(2).a(9).COMPLEX16
#      |
#      |  __dict__
#      |      Ylm2 : a(2).a(5).COMPLEX16
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class PNPhasingSeries(builtins.SwigPyObject)
#      |  ::tagPNPhasingSeries
#      |
#      |  Method resolution order:
#      |      PNPhasingSeries
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(PNPhasingSeries self) -> PNPhasingSeries
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(PNPhasingSeries self, void const * memo) -> PNPhasingSeries
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      XLALSimInspiralCreateTestGRParam : p.LALSimInspiralTestGRParam
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  v
#      |      v : a(15+1).REAL8
#      |
#      |  vlogv
#      |      vlogv : a(15+1).REAL8
#      |
#      |  vlogvsq
#      |      vlogvsq : a(15+1).REAL8
#      |
#      |  vneg
#      |      vneg : a(15+1).REAL8
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralGenerator(builtins.SwigPyObject)
#      |  ::tagLALSimInspiralGenerator
#      |
#      |  Method resolution order:
#      |      SimInspiralGenerator
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralGenerator self) -> SimInspiralGenerator
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralGenerator self, void const * memo) -> SimInspiralGenerator
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ~tagLALSimInspiralGenerator : void
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralSpinTaylorTxCoeffs(builtins.SwigPyObject)
#      |  ::tagXLALSimInspiralSpinTaylorTxCoeffs
#      |
#      |  Method resolution order:
#      |      SimInspiralSpinTaylorTxCoeffs
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralSpinTaylorTxCoeffs self) -> SimInspiralSpinTaylorTxCoeffs
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralSpinTaylorTxCoeffs self, void const * memo) -> SimInspiralSpinTaylorTxCoeffs
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  E3S1O
#      |      E3S1O : REAL8
#      |
#      |  E3S2O
#      |      E3S2O : REAL8
#      |
#      |  E4QMS1OS1OAvg
#      |      E4QMS1OS1OAvg : REAL8
#      |
#      |  E4QMS1S1Avg
#      |      E4QMS1S1Avg : REAL8
#      |
#      |  E4QMS2OS2OAvg
#      |      E4QMS2OS2OAvg : REAL8
#      |
#      |  E4QMS2S2Avg
#      |      E4QMS2S2Avg : REAL8
#      |
#      |  E4S1OS2OAvg
#      |      E4S1OS2OAvg : REAL8
#      |
#      |  E4S1S2Avg
#      |      E4S1S2Avg : REAL8
#      |
#      |  E5S1O
#      |      E5S1O : REAL8
#      |
#      |  E5S2O
#      |      E5S2O : REAL8
#      |
#      |  E6QMS1OS1OAvg
#      |      E6QMS1OS1OAvg : REAL8
#      |
#      |  E6QMS1S1
#      |      E6QMS1S1 : REAL8
#      |
#      |  E6QMS1S1Avg
#      |      E6QMS1S1Avg : REAL8
#      |
#      |  E6QMS1nS1n
#      |      E6QMS1nS1n : REAL8
#      |
#      |  E6QMS1vS1v
#      |      E6QMS1vS1v : REAL8
#      |
#      |  E6QMS2OS2OAvg
#      |      E6QMS2OS2OAvg : REAL8
#      |
#      |  E6QMS2S2
#      |      E6QMS2S2 : REAL8
#      |
#      |  E6QMS2S2Avg
#      |      E6QMS2S2Avg : REAL8
#      |
#      |  E6QMS2nS2n
#      |      E6QMS2nS2n : REAL8
#      |
#      |  E6QMS2vS2v
#      |      E6QMS2vS2v : REAL8
#      |
#      |  E6S1OS1OAvg
#      |      E6S1OS1OAvg : REAL8
#      |
#      |  E6S1OS2OAvg
#      |      E6S1OS2OAvg : REAL8
#      |
#      |  E6S1S1Avg
#      |      E6S1S1Avg : REAL8
#      |
#      |  E6S1S2Avg
#      |      E6S1S2Avg : REAL8
#      |
#      |  E6S2OS2OAvg
#      |      E6S2OS2OAvg : REAL8
#      |
#      |  E6S2S2Avg
#      |      E6S2S2Avg : REAL8
#      |
#      |  E7S1O
#      |      E7S1O : REAL8
#      |
#      |  E7S2O
#      |      E7S2O : REAL8
#      |
#      |  Ecoeff
#      |      Ecoeff : a(8).REAL8
#      |
#      |  Etidal10
#      |      Etidal10 : REAL8
#      |
#      |  Etidal12
#      |      Etidal12 : REAL8
#      |
#      |  F3S1O
#      |      F3S1O : REAL8
#      |
#      |  F3S2O
#      |      F3S2O : REAL8
#      |
#      |  F4QMS1OS1OAvg
#      |      F4QMS1OS1OAvg : REAL8
#      |
#      |  F4QMS1S1
#      |      F4QMS1S1 : REAL8
#      |
#      |  F4QMS1S1Avg
#      |      F4QMS1S1Avg : REAL8
#      |
#      |  F4QMS1nS1n
#      |      F4QMS1nS1n : REAL8
#      |
#      |  F4QMS1vS1v
#      |      F4QMS1vS1v : REAL8
#      |
#      |  F4QMS2OS2OAvg
#      |      F4QMS2OS2OAvg : REAL8
#      |
#      |  F4QMS2S2
#      |      F4QMS2S2 : REAL8
#      |
#      |  F4QMS2S2Avg
#      |      F4QMS2S2Avg : REAL8
#      |
#      |  F4QMS2nS2n
#      |      F4QMS2nS2n : REAL8
#      |
#      |  F4QMS2vS2v
#      |      F4QMS2vS2v : REAL8
#      |
#      |  F4S1OS1OAvg
#      |      F4S1OS1OAvg : REAL8
#      |
#      |  F4S1OS2OAvg
#      |      F4S1OS2OAvg : REAL8
#      |
#      |  F4S1S1Avg
#      |      F4S1S1Avg : REAL8
#      |
#      |  F4S1S2Avg
#      |      F4S1S2Avg : REAL8
#      |
#      |  F4S2OS2OAvg
#      |      F4S2OS2OAvg : REAL8
#      |
#      |  F4S2S2Avg
#      |      F4S2S2Avg : REAL8
#      |
#      |  F5S1O
#      |      F5S1O : REAL8
#      |
#      |  F5S2O
#      |      F5S2O : REAL8
#      |
#      |  F6QMS1OS1OAvg
#      |      F6QMS1OS1OAvg : REAL8
#      |
#      |  F6QMS1S1Avg
#      |      F6QMS1S1Avg : REAL8
#      |
#      |  F6QMS2OS2OAvg
#      |      F6QMS2OS2OAvg : REAL8
#      |
#      |  F6QMS2S2Avg
#      |      F6QMS2S2Avg : REAL8
#      |
#      |  F6S1O
#      |      F6S1O : REAL8
#      |
#      |  F6S1OS1OAvg
#      |      F6S1OS1OAvg : REAL8
#      |
#      |  F6S1OS2OAvg
#      |      F6S1OS2OAvg : REAL8
#      |
#      |  F6S1S1Avg
#      |      F6S1S1Avg : REAL8
#      |
#      |  F6S1S2Avg
#      |      F6S1S2Avg : REAL8
#      |
#      |  F6S2O
#      |      F6S2O : REAL8
#      |
#      |  F6S2OS2OAvg
#      |      F6S2OS2OAvg : REAL8
#      |
#      |  F6S2S2Avg
#      |      F6S2S2Avg : REAL8
#      |
#      |  F7S1O
#      |      F7S1O : REAL8
#      |
#      |  F7S2O
#      |      F7S2O : REAL8
#      |
#      |  Fcoeff
#      |      Fcoeff : a(8).REAL8
#      |
#      |  Flogcoeff
#      |      Flogcoeff : REAL8
#      |
#      |  Fnewt
#      |      Fnewt : REAL8
#      |
#      |  Ftidal10
#      |      Ftidal10 : REAL8
#      |
#      |  Ftidal12
#      |      Ftidal12 : REAL8
#      |
#      |  M
#      |      M : REAL8
#      |
#      |  Mchirp
#      |      Mchirp : REAL8
#      |
#      |  S1dot3
#      |      S1dot3 : REAL8
#      |
#      |  S1dot4QMS1OAvg
#      |      S1dot4QMS1OAvg : REAL8
#      |
#      |  S1dot4S2Avg
#      |      S1dot4S2Avg : REAL8
#      |
#      |  S1dot4S2OAvg
#      |      S1dot4S2OAvg : REAL8
#      |
#      |  S1dot5
#      |      S1dot5 : REAL8
#      |
#      |  S1dot6QMS1OAvg
#      |      S1dot6QMS1OAvg : REAL8
#      |
#      |  S1dot6S1OAvg
#      |      S1dot6S1OAvg : REAL8
#      |
#      |  S1dot6S2Avg
#      |      S1dot6S2Avg : REAL8
#      |
#      |  S1dot6S2OAvg
#      |      S1dot6S2OAvg : REAL8
#      |
#      |  S1dot7S2
#      |      S1dot7S2 : REAL8
#      |
#      |  S2dot3
#      |      S2dot3 : REAL8
#      |
#      |  S2dot4QMS2OAvg
#      |      S2dot4QMS2OAvg : REAL8
#      |
#      |  S2dot5
#      |      S2dot5 : REAL8
#      |
#      |  S2dot6QMS2OAvg
#      |      S2dot6QMS2OAvg : REAL8
#      |
#      |  S2dot6S1Avg
#      |      S2dot6S1Avg : REAL8
#      |
#      |  S2dot6S1OAvg
#      |      S2dot6S1OAvg : REAL8
#      |
#      |  S2dot6S2OAvg
#      |      S2dot6S2OAvg : REAL8
#      |
#      |  S2dot7S1
#      |      S2dot7S1 : REAL8
#      |
#      |  __dict__
#      |      XLALSimInspiralChooseTDWaveform : int
#      |
#      |  dEdvnewt
#      |      dEdvnewt : REAL8
#      |
#      |  eta
#      |      eta : REAL8
#      |
#      |  fEnd
#      |      fEnd : REAL8
#      |
#      |  fStart
#      |      fStart : REAL8
#      |
#      |  lscorr
#      |      lscorr : INT4
#      |
#      |  m1M
#      |      m1M : REAL8
#      |
#      |  m2M
#      |      m2M : REAL8
#      |
#      |  omegashiftS1
#      |      omegashiftS1 : REAL8
#      |
#      |  omegashiftS2
#      |      omegashiftS2 : REAL8
#      |
#      |  phaseO
#      |      phaseO : INT4
#      |
#      |  phenomtp
#      |      phenomtp : INT4
#      |
#      |  prev_domega
#      |      prev_domega : REAL8
#      |
#      |  spinO
#      |      spinO : LALSimInspiralSpinOrder
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  tideO
#      |      tideO : LALSimInspiralTidalOrder
#      |
#      |  wdot3S1O
#      |      wdot3S1O : REAL8
#      |
#      |  wdot3S2O
#      |      wdot3S2O : REAL8
#      |
#      |  wdot4QMS1OS1OAvg
#      |      wdot4QMS1OS1OAvg : REAL8
#      |
#      |  wdot4QMS1S1Avg
#      |      wdot4QMS1S1Avg : REAL8
#      |
#      |  wdot4QMS2OS2OAvg
#      |      wdot4QMS2OS2OAvg : REAL8
#      |
#      |  wdot4QMS2S2Avg
#      |      wdot4QMS2S2Avg : REAL8
#      |
#      |  wdot4S1OS1OAvg
#      |      wdot4S1OS1OAvg : REAL8
#      |
#      |  wdot4S1OS2OAvg
#      |      wdot4S1OS2OAvg : REAL8
#      |
#      |  wdot4S1S1Avg
#      |      wdot4S1S1Avg : REAL8
#      |
#      |  wdot4S1S2Avg
#      |      wdot4S1S2Avg : REAL8
#      |
#      |  wdot4S2OS2OAvg
#      |      wdot4S2OS2OAvg : REAL8
#      |
#      |  wdot4S2S2Avg
#      |      wdot4S2S2Avg : REAL8
#      |
#      |  wdot5S1O
#      |      wdot5S1O : REAL8
#      |
#      |  wdot5S2O
#      |      wdot5S2O : REAL8
#      |
#      |  wdot6QMS1OS1OAvg
#      |      wdot6QMS1OS1OAvg : REAL8
#      |
#      |  wdot6QMS1S1
#      |      wdot6QMS1S1 : REAL8
#      |
#      |  wdot6QMS1S1Avg
#      |      wdot6QMS1S1Avg : REAL8
#      |
#      |  wdot6QMS1nS1n
#      |      wdot6QMS1nS1n : REAL8
#      |
#      |  wdot6QMS1vS1v
#      |      wdot6QMS1vS1v : REAL8
#      |
#      |  wdot6QMS2OS2OAvg
#      |      wdot6QMS2OS2OAvg : REAL8
#      |
#      |  wdot6QMS2S2
#      |      wdot6QMS2S2 : REAL8
#      |
#      |  wdot6QMS2S2Avg
#      |      wdot6QMS2S2Avg : REAL8
#      |
#      |  wdot6QMS2nS2n
#      |      wdot6QMS2nS2n : REAL8
#      |
#      |  wdot6QMS2vS2v
#      |      wdot6QMS2vS2v : REAL8
#      |
#      |  wdot6S1O
#      |      wdot6S1O : REAL8
#      |
#      |  wdot6S1OS1OAvg
#      |      wdot6S1OS1OAvg : REAL8
#      |
#      |  wdot6S1OS2OAvg
#      |      wdot6S1OS2OAvg : REAL8
#      |
#      |  wdot6S1S1Avg
#      |      wdot6S1S1Avg : REAL8
#      |
#      |  wdot6S1S2Avg
#      |      wdot6S1S2Avg : REAL8
#      |
#      |  wdot6S2O
#      |      wdot6S2O : REAL8
#      |
#      |  wdot6S2OS2OAvg
#      |      wdot6S2OS2OAvg : REAL8
#      |
#      |  wdot6S2S2Avg
#      |      wdot6S2S2Avg : REAL8
#      |
#      |  wdot7S1O
#      |      wdot7S1O : REAL8
#      |
#      |  wdot7S2O
#      |      wdot7S2O : REAL8
#      |
#      |  wdotcoeff
#      |      wdotcoeff : a(8).REAL8
#      |
#      |  wdotlogcoeff
#      |      wdotlogcoeff : REAL8
#      |
#      |  wdotnewt
#      |      wdotnewt : REAL8
#      |
#      |  wdottidal10
#      |      wdottidal10 : REAL8
#      |
#      |  wdottidal12
#      |      wdottidal12 : REAL8
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralTestGRParam(builtins.SwigPyObject)
#      |  ::tagLALSimInspiralTestGRParam
#      |
#      |  Method resolution order:
#      |      SimInspiralTestGRParam
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralTestGRParam self) -> SimInspiralTestGRParam
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralTestGRParam self, void const * memo) -> SimInspiralTestGRParam
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      data : p.struct tagLALSimInspiralTestGRParamData
#      |
#      |  data
#      |      data : p.struct tagLALSimInspiralTestGRParamData
#      |
#      |  next
#      |      next : p.struct tagLALSimInspiralTestGRParam
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralTestGRParamData(builtins.SwigPyObject)
#      |  ::tagLALSimInspiralTestGRParamData
#      |
#      |  Method resolution order:
#      |      SimInspiralTestGRParamData
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralTestGRParamData self) -> SimInspiralTestGRParamData
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralTestGRParamData self, void const * memo) -> SimInspiralTestGRParamData
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      XLALSphHarmTimeSeriesAddMode : p.SphHarmTimeSeries
#      |
#      |  name
#      |      name : a(32).char
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  value
#      |      value : double
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralWaveformCache(builtins.SwigPyObject)
#      |  ::tagLALSimInspiralWaveformCache
#      |
#      |  Method resolution order:
#      |      SimInspiralWaveformCache
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralWaveformCache self) -> SimInspiralWaveformCache
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralWaveformCache self, void const * memo) -> SimInspiralWaveformCache
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  LALpars
#      |      LALpars : p.LALDict
#      |
#      |  S1x
#      |      S1x : REAL8
#      |
#      |  S1y
#      |      S1y : REAL8
#      |
#      |  S1z
#      |      S1z : REAL8
#      |
#      |  S2x
#      |      S2x : REAL8
#      |
#      |  S2y
#      |      S2y : REAL8
#      |
#      |  S2z
#      |      S2z : REAL8
#      |
#      |  __dict__
#      |      hplus : p.REAL8TimeSeries
#      |
#      |  approximant
#      |      approximant : Approximant
#      |
#      |  deltaTF
#      |      deltaTF : REAL8
#      |
#      |  f_max
#      |      f_max : REAL8
#      |
#      |  f_min
#      |      f_min : REAL8
#      |
#      |  f_ref
#      |      f_ref : REAL8
#      |
#      |  frequencies
#      |      frequencies : p.REAL8Sequence
#      |
#      |  hcross
#      |      hcross : p.REAL8TimeSeries
#      |
#      |  hctilde
#      |      hctilde : p.COMPLEX16FrequencySeries
#      |
#      |  hplus
#      |      hplus : p.REAL8TimeSeries
#      |
#      |  hptilde
#      |      hptilde : p.COMPLEX16FrequencySeries
#      |
#      |  i
#      |      i : REAL8
#      |
#      |  m1
#      |      m1 : REAL8
#      |
#      |  m2
#      |      m2 : REAL8
#      |
#      |  phiRef
#      |      phiRef : REAL8
#      |
#      |  r
#      |      r : REAL8
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralWaveformCacheOld(builtins.SwigPyObject)
#      |  ::tagLALSimInspiralWaveformCacheOld
#      |
#      |  Method resolution order:
#      |      SimInspiralWaveformCacheOld
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralWaveformCacheOld self) -> SimInspiralWaveformCacheOld
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralWaveformCacheOld self, void const * memo) -> SimInspiralWaveformCacheOld
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  S1x
#      |      S1x : REAL8
#      |
#      |  S1y
#      |      S1y : REAL8
#      |
#      |  S1z
#      |      S1z : REAL8
#      |
#      |  S2x
#      |      S2x : REAL8
#      |
#      |  S2y
#      |      S2y : REAL8
#      |
#      |  S2z
#      |      S2z : REAL8
#      |
#      |  __dict__
#      |      XLALSimInspiralInjectionSequenceFromH5File : p.LALDictSequence
#      |
#      |  amplitudeO
#      |      amplitudeO : int
#      |
#      |  approximant
#      |      approximant : Approximant
#      |
#      |  deltaTF
#      |      deltaTF : REAL8
#      |
#      |  f_max
#      |      f_max : REAL8
#      |
#      |  f_min
#      |      f_min : REAL8
#      |
#      |  f_ref
#      |      f_ref : REAL8
#      |
#      |  frequencies
#      |      frequencies : p.REAL8Sequence
#      |
#      |  hcross
#      |      hcross : p.REAL8TimeSeries
#      |
#      |  hctilde
#      |      hctilde : p.COMPLEX16FrequencySeries
#      |
#      |  hplus
#      |      hplus : p.REAL8TimeSeries
#      |
#      |  hptilde
#      |      hptilde : p.COMPLEX16FrequencySeries
#      |
#      |  i
#      |      i : REAL8
#      |
#      |  lambda1
#      |      lambda1 : REAL8
#      |
#      |  lambda2
#      |      lambda2 : REAL8
#      |
#      |  m1
#      |      m1 : REAL8
#      |
#      |  m2
#      |      m2 : REAL8
#      |
#      |  nonGRparams
#      |      nonGRparams : p.LALSimInspiralTestGRParam
#      |
#      |  phaseO
#      |      phaseO : int
#      |
#      |  phiRef
#      |      phiRef : REAL8
#      |
#      |  r
#      |      r : REAL8
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  waveFlags
#      |      waveFlags : p.LALSimInspiralWaveformFlags
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimInspiralWaveformFlags(builtins.SwigPyObject)
#      |  ::tagLALSimInspiralWaveformFlags
#      |
#      |  Method resolution order:
#      |      SimInspiralWaveformFlags
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimInspiralWaveformFlags self) -> SimInspiralWaveformFlags
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimInspiralWaveformFlags self, void const * memo) -> SimInspiralWaveformFlags
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ~tagLALSimInspiralWaveformFlags : void
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimNeutronStarEOS(builtins.SwigPyObject)
#      |  ::tagLALSimNeutronStarEOS
#      |
#      |  Method resolution order:
#      |      SimNeutronStarEOS
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimNeutronStarEOS self) -> SimNeutronStarEOS
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimNeutronStarEOS self, void const * memo) -> SimNeutronStarEOS
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ~tagLALSimNeutronStarEOS : void
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SimNeutronStarFamily(builtins.SwigPyObject)
#      |  ::tagLALSimNeutronStarFamily
#      |
#      |  Method resolution order:
#      |      SimNeutronStarFamily
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SimNeutronStarFamily self) -> SimNeutronStarFamily
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SimNeutronStarFamily self, void const * memo) -> SimNeutronStarFamily
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.SwigPyObjectType
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ~tagLALSimNeutronStarFamily : void
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.SwigPyObject:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __int__(self, /)
#      |      int(self)
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SphHarmFrequencySeries(builtins.SwigPyObject)
#      |  ::tagSphHarmFrequencySeries
#      |
#      |  Method resolution order:
#      |      SphHarmFrequencySeries
#      |      builtins.SwigPyObject
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(...)
#      |      __copy__(SphHarmFrequencySeries self) -> SphHarmFrequencySeries
#      |
#      |  __deepcopy__(...)
#      |      __deepcopy__(SphHarmFrequencySeries self, void const * memo) -> SphHarmFrequencySeries
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __setattr__(self, name, value, /)
# ...
#     IMRPhenomTPGeneratorTemplate = <Swig Object of type 'tagLALSimInspiral...
#     IMRPhenomTPHM = 106
#     IMRPhenomTPHMGeneratorTemplate = <Swig Object of type 'tagLALSimInspir...
#     IMRPhenomXAS = 96
#     IMRPhenomXASGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     IMRPhenomXAS_NRTidalv2 = 110
#     IMRPhenomXAS_NRTidalv2GeneratorTemplate = <Swig Object of type 'tagLAL...
#     IMRPhenomXAS_NRTidalv3 = 115
#     IMRPhenomXAS_NRTidalv3GeneratorTemplate = <Swig Object of type 'tagLAL...
#     IMRPhenomXHM = 97
#     IMRPhenomXHMGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     IMRPhenomXO4a = 112
#     IMRPhenomXO4aGeneratorTemplate = <Swig Object of type 'tagLALSimInspir...
#     IMRPhenomXP = 100
#     IMRPhenomXPGeneratorTemplate = <Swig Object of type 'tagLALSimInspiral...
#     IMRPhenomXPHM = 101
#     IMRPhenomXPHMGeneratorTemplate = <Swig Object of type 'tagLALSimInspir...
#     IMRPhenomXP_NRTidalv2 = 111
#     IMRPhenomXP_NRTidalv2GeneratorTemplate = <Swig Object of type 'tagLALS...
#     IMRPhenomXP_NRTidalv3 = 116
#     IMRPhenomXP_NRTidalv3GeneratorTemplate = <Swig Object of type 'tagLALS...
#     LALSIMULATION_VERSION = '6.0.0'
#     LALSIMULATION_VERSION_DEVEL = 0
#     LALSIMULATION_VERSION_MAJOR = 6
#     LALSIMULATION_VERSION_MICRO = 0
#     LALSIMULATION_VERSION_MINOR = 0
#     Lackey_Tidal_2013_SEOBNRv2_ROM = 60
#     Lackey_Tidal_2013_SEOBNRv2_ROMGeneratorTemplate = <Swig Object of type...
#     MAX_ECC_PN_ORDER = 6
#     MAX_PN_ORDER = 8
#     NINE_OVER_32 = 0.28125
#     NRHybSur3dq8 = 95
#     NRHybSur3dq8GeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     NRSur4d2s = 91
#     NRSur4d2sGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGe...
#     NRSur7dq2 = 92
#     NRSur7dq2GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGe...
#     NRSur7dq4 = 93
#     NRSur7dq4GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGe...
#     NRTidal_V = 0
#     NRTidalv2NSBH_V = 5
#     NRTidalv2NoAmpCorr_V = 3
#     NRTidalv2_V = 1
#     NRTidalv3NoAmpCorr_V = 4
#     NRTidalv3_V = 2
#     NR_hdf5 = 90
#     NR_hdf5GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGene...
#     NUCLEAR_DENSITY_SI = 2.8e+17
#     NoNRT_V = 6
#     NumApproximants = 118
#     NumFreqFunctions = 16
#     NumRel = 33
#     NumRelNinja2 = 34
#     ONE_OVER_128 = 0.0078125
#     ONE_OVER_16 = 0.0625
#     ONE_OVER_32 = 0.03125
#     ONE_OVER_EIGHT = 0.125
#     ONE_OVER_FOUR = 0.25
#     ONE_OVER_TWO = 0.5
#     PNORDER_HALF = 1
#     PNORDER_NEWTONIAN = 0
#     PNORDER_NUM_ORDER = 9
#     PNORDER_ONE = 2
#     PNORDER_ONE_POINT_FIVE = 3
#     PNORDER_PSEUDO_FOUR = 8
#     PNORDER_THREE = 6
#     PNORDER_THREE_POINT_FIVE = 7
#     PNORDER_TWO = 4
#     PNORDER_TWO_POINT_FIVE = 5
#     PN_MODE_L_MAX = 3
#     PN_PHASING_SERIES_MAX_ORDER = 15
#     PadeF1 = 12
#     PadeT1 = 11
#     PhenSpinTaylor = 24
#     PhenSpinTaylorGeneratorTemplate = <Swig Object of type 'tagLALSimInspi...
#     PhenSpinTaylorRD = 25
#     PhenSpinTaylorRDGeneratorTemplate = <Swig Object of type 'tagLALSimIns...
#     PythonGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGener...
#     SEOBNRv1 = 42
#     SEOBNRv1GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     SEOBNRv1_ROM_DoubleSpin = 56
#     SEOBNRv1_ROM_DoubleSpinGeneratorTemplate = <Swig Object of type 'tagLA...
#     SEOBNRv1_ROM_EffectiveSpin = 55
#     SEOBNRv1_ROM_EffectiveSpinGeneratorTemplate = <Swig Object of type 'ta...
#     SEOBNRv2 = 43
#     SEOBNRv2GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     SEOBNRv2T = 53
#     SEOBNRv2TGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGe...
#     SEOBNRv2_ROM_DoubleSpin = 58
#     SEOBNRv2_ROM_DoubleSpinGeneratorTemplate = <Swig Object of type 'tagLA...
#     SEOBNRv2_ROM_DoubleSpin_HI = 59
#     SEOBNRv2_ROM_DoubleSpin_HIGeneratorTemplate = <Swig Object of type 'ta...
#     SEOBNRv2_ROM_EffectiveSpin = 57
#     SEOBNRv2_ROM_EffectiveSpinGeneratorTemplate = <Swig Object of type 'ta...
#     SEOBNRv2_opt = 44
#     SEOBNRv2_optGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SEOBNRv3 = 45
#     SEOBNRv3GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     SEOBNRv3_opt = 47
#     SEOBNRv3_optGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SEOBNRv3_opt_rk4 = 48
#     SEOBNRv3_opt_rk4GeneratorTemplate = <Swig Object of type 'tagLALSimIns...
#     SEOBNRv3_pert = 46
#     SEOBNRv3_pertGeneratorTemplate = <Swig Object of type 'tagLALSimInspir...
#     SEOBNRv4 = 49
#     SEOBNRv4GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     SEOBNRv4HM = 94
#     SEOBNRv4HMGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralG...
#     SEOBNRv4HM_PA = 108
#     SEOBNRv4HM_PAGeneratorTemplate = <Swig Object of type 'tagLALSimInspir...
#     SEOBNRv4HM_ROM = 62
#     SEOBNRv4HM_ROMGeneratorTemplate = <Swig Object of type 'tagLALSimInspi...
#     SEOBNRv4P = 51
#     SEOBNRv4PGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGe...
#     SEOBNRv4PHM = 52
#     SEOBNRv4PHMGeneratorTemplate = <Swig Object of type 'tagLALSimInspiral...
#     SEOBNRv4T = 54
#     SEOBNRv4TGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGe...
#     SEOBNRv4TSurrogate_CUBIC = 0
#     SEOBNRv4TSurrogate_LINEAR = 1
#     SEOBNRv4T_surrogate = 66
#     SEOBNRv4T_surrogateGeneratorTemplate = <Swig Object of type 'tagLALSim...
#     SEOBNRv4_ROM = 61
#     SEOBNRv4_ROMGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SEOBNRv4_ROM_NRTidal = 63
#     SEOBNRv4_ROM_NRTidalGeneratorTemplate = <Swig Object of type 'tagLALSi...
#     SEOBNRv4_ROM_NRTidalv2 = 64
#     SEOBNRv4_ROM_NRTidalv2GeneratorTemplate = <Swig Object of type 'tagLAL...
#     SEOBNRv4_ROM_NRTidalv2_NSBH = 65
#     SEOBNRv4_ROM_NRTidalv2_NSBHGeneratorTemplate = <Swig Object of type 't...
#     SEOBNRv4_opt = 50
#     SEOBNRv4_optGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SEOBNRv5HM_ROM = 114
#     SEOBNRv5HM_ROMGeneratorTemplate = <Swig Object of type 'tagLALSimInspi...
#     SEOBNRv5_ROM = 107
#     SEOBNRv5_ROMGeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SEOBNRv5_ROM_NRTidalv3 = 117
#     SEOBNRv5_ROM_NRTidalv3GeneratorTemplate = <Swig Object of type 'tagLAL...
#     SEVEN_OVER_16 = 0.4375
#     SEVEN_OVER_32 = 0.21875
#     SIM_DOMAIN_FREQUENCY = 1
#     SIM_DOMAIN_TIME = 0
#     SIM_INSPIRAL_ALIGNEDSPIN = 2
#     SIM_INSPIRAL_ALLOW_ZERO_FMIN = 0
#     SIM_INSPIRAL_CASEBYCASE_SPINSUPPORT = 4
#     SIM_INSPIRAL_CASEBYCASE_TESTGR_PARAMS = 2
#     SIM_INSPIRAL_DISALLOW_ZERO_FMIN = 1
#     SIM_INSPIRAL_EOS_A = 2
#     SIM_INSPIRAL_EOS_APR = 5
#     SIM_INSPIRAL_EOS_AU = 3
#     SIM_INSPIRAL_EOS_FPS = 4
#     SIM_INSPIRAL_EOS_GNH3 = 12
#     SIM_INSPIRAL_EOS_H4 = 9
#     SIM_INSPIRAL_EOS_L = 7
#     SIM_INSPIRAL_EOS_Lambda_q_Specific = 1
#     SIM_INSPIRAL_EOS_MPA1 = 11
#     SIM_INSPIRAL_EOS_MS1 = 8
#     SIM_INSPIRAL_EOS_NONE = 0
#     SIM_INSPIRAL_EOS_SQM3 = 10
#     SIM_INSPIRAL_EOS_UU = 6
#     SIM_INSPIRAL_FRAME_AXIS_ORBITAL_L = 2
#     SIM_INSPIRAL_FRAME_AXIS_TOTAL_J = 1
#     SIM_INSPIRAL_FRAME_AXIS_VIEW = 0
#     SIM_INSPIRAL_GETIDES_GSF2 = 2
#     SIM_INSPIRAL_GETIDES_GSF23 = 3
#     SIM_INSPIRAL_GETIDES_NNLO = 1
#     SIM_INSPIRAL_GETIDES_NOPT = 4
#     SIM_INSPIRAL_GETIDES_OFF = 0
#     SIM_INSPIRAL_GMTIDES_GSF = 2
#     SIM_INSPIRAL_GMTIDES_NOPT = 3
#     SIM_INSPIRAL_GMTIDES_OFF = 0
#     SIM_INSPIRAL_GMTIDES_PN = 1
#     SIM_INSPIRAL_MODES_CHOICE_2AND3AND4AND5L = 15
#     SIM_INSPIRAL_MODES_CHOICE_2AND3AND4L = 7
#     SIM_INSPIRAL_MODES_CHOICE_2AND3AND5L = 11
#     SIM_INSPIRAL_MODES_CHOICE_2AND3L = 3
#     SIM_INSPIRAL_MODES_CHOICE_2AND4AND5L = 13
#     SIM_INSPIRAL_MODES_CHOICE_2AND4L = 5
#     SIM_INSPIRAL_MODES_CHOICE_2AND5L = 9
#     SIM_INSPIRAL_MODES_CHOICE_3AND4AND5L = 14
#     SIM_INSPIRAL_MODES_CHOICE_3AND4L = 6
#     SIM_INSPIRAL_MODES_CHOICE_3AND5L = 10
#     SIM_INSPIRAL_MODES_CHOICE_3L = 2
#     SIM_INSPIRAL_MODES_CHOICE_4AND5L = 12
#     SIM_INSPIRAL_MODES_CHOICE_4L = 4
#     SIM_INSPIRAL_MODES_CHOICE_5L = 8
#     SIM_INSPIRAL_MODES_CHOICE_ALL = -1
#     SIM_INSPIRAL_MODES_CHOICE_RESTRICTED = 1
#     SIM_INSPIRAL_NO_TESTGR_PARAMS = 0
#     SIM_INSPIRAL_NUMSPINFREQ = 4
#     SIM_INSPIRAL_NUMSPINSUPPORT = 5
#     SIM_INSPIRAL_NUMZEROFMIN = 2
#     SIM_INSPIRAL_NUM_TESTGR_ACCEPT = 3
#     SIM_INSPIRAL_NumEOS = 13
#     SIM_INSPIRAL_PRECESSINGSPIN = 3
#     SIM_INSPIRAL_SINGLESPIN = 1
#     SIM_INSPIRAL_SPINLESS = 0
#     SIM_INSPIRAL_SPINS_CASEBYCASE = 3
#     SIM_INSPIRAL_SPINS_FLOW = 1
#     SIM_INSPIRAL_SPINS_F_REF = 0
#     SIM_INSPIRAL_SPINS_NONPRECESSING = 2
#     SIM_INSPIRAL_SPIN_ORDER_05PN = 1
#     SIM_INSPIRAL_SPIN_ORDER_0PN = 0
#     SIM_INSPIRAL_SPIN_ORDER_15PN = 3
#     SIM_INSPIRAL_SPIN_ORDER_1PN = 2
#     SIM_INSPIRAL_SPIN_ORDER_25PN = 5
#     SIM_INSPIRAL_SPIN_ORDER_2PN = 4
#     SIM_INSPIRAL_SPIN_ORDER_35PN = 7
#     SIM_INSPIRAL_SPIN_ORDER_3PN = 6
#     SIM_INSPIRAL_SPIN_ORDER_ALL = -1
#     SIM_INSPIRAL_TAPER_END = 2
#     SIM_INSPIRAL_TAPER_NONE = 0
#     SIM_INSPIRAL_TAPER_NUM_OPTS = 4
#     SIM_INSPIRAL_TAPER_START = 1
#     SIM_INSPIRAL_TAPER_STARTEND = 3
#     SIM_INSPIRAL_TESTGR_PARAMS = 1
#     SIM_INSPIRAL_TIDAL_ORDER_0PN = 0
#     SIM_INSPIRAL_TIDAL_ORDER_5PN = 10
#     SIM_INSPIRAL_TIDAL_ORDER_65PN = 13
#     SIM_INSPIRAL_TIDAL_ORDER_6PN = 12
#     SIM_INSPIRAL_TIDAL_ORDER_75PN = 15
#     SIM_INSPIRAL_TIDAL_ORDER_7PN = 14
#     SIM_INSPIRAL_TIDAL_ORDER_ALL = -1
#     SIM_L_MAX_MODE_ARRAY = 8
#     SQRT_10_OVER_32 = 0.09882117688026186
#     SQRT_14_OVER_32 = 0.11692679333668567
#     SQRT_15_OVER_32 = 0.12103072956898178
#     SQRT_2_OVER_64 = 0.02209708691207961
#     SQRT_30_OVER_16 = 0.3423265984407288
#     SQRT_35_OVER_4 = 1.479019945774904
#     SQRT_5_OVER_16 = 0.13975424859373686
#     SQRT_6 = 2.449489742783178
#     SQRT_6_OVER_32 = 0.07654655446197431
#     SQRT_70_16 = 0.5229125165837972
#     SQRT_7_OVER_16 = 0.16535945694153692
#     SQRT_7_OVER_32 = 0.08267972847076846
#     SimNeutronStarEOSNames = array(['ALF1', 'ALF2', 'ALF3', 'ALF4', 'AP1',...
#     SimNoisePSDAdvVirgoPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDGEOHFPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDGEOPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDKAGRAPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDTAMAPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDVirgoPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDaLIGOBHBH20DegPtr = <Swig Object of type 'double (*)(double...
#     SimNoisePSDaLIGOHighFrequencyPtr = <Swig Object of type 'double (*)(do...
#     SimNoisePSDaLIGONSNSOptPtr = <Swig Object of type 'double (*)(double)'...
#     SimNoisePSDaLIGONoSRMHighPowerPtr = <Swig Object of type 'double (*)(d...
#     SimNoisePSDaLIGONoSRMLowPowerPtr = <Swig Object of type 'double (*)(do...
#     SimNoisePSDaLIGOQuantumBHBH20DegPtr = <Swig Object of type 'double (*)...
#     SimNoisePSDaLIGOQuantumHighFrequencyPtr = <Swig Object of type 'double...
#     SimNoisePSDaLIGOQuantumNSNSOptPtr = <Swig Object of type 'double (*)(d...
#     SimNoisePSDaLIGOQuantumNoSRMHighPowerPtr = <Swig Object of type 'doubl...
#     SimNoisePSDaLIGOQuantumNoSRMLowPowerPtr = <Swig Object of type 'double...
#     SimNoisePSDaLIGOQuantumZeroDetHighPowerPtr = <Swig Object of type 'dou...
#     SimNoisePSDaLIGOQuantumZeroDetLowPowerPtr = <Swig Object of type 'doub...
#     SimNoisePSDaLIGOThermalPtr = <Swig Object of type 'double (*)(double)'...
#     SimNoisePSDaLIGOZeroDetHighPowerPtr = <Swig Object of type 'double (*)...
#     SimNoisePSDaLIGOZeroDetLowPowerPtr = <Swig Object of type 'double (*)(...
#     SimNoisePSDeLIGOModelPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDeLIGOShotPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDiLIGOModelPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDiLIGOSRDPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDiLIGOSeismicPtr = <Swig Object of type 'double (*)(double)'...
#     SimNoisePSDiLIGOShotPtr = <Swig Object of type 'double (*)(double)'>
#     SimNoisePSDiLIGOThermalPtr = <Swig Object of type 'double (*)(double)'...
#     SimulationVCSIdentInfo = <Swig Object of type 'tagLALVCSInfo *'>
#     SimulationVCSInfo = <Swig Object of type 'tagLALVCSInfo *'>
#     SimulationVCSInfoList = array([<Swig Object of type 'tagLALVCSInfo *' ...
#     SpinDominatedWf = 89
#     SpinDominatedWfGeneratorTemplate = <Swig Object of type 'tagLALSimInsp...
#     SpinQuadTaylor = 26
#     SpinTaylor = 23
#     SpinTaylorF2 = 21
#     SpinTaylorF2GeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SpinTaylorFrameless = 22
#     SpinTaylorT1 = 16
#     SpinTaylorT1GeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SpinTaylorT2 = 17
#     SpinTaylorT3 = 18
#     SpinTaylorT4 = 19
#     SpinTaylorT4Fourier = 87
#     SpinTaylorT4FourierGeneratorTemplate = <Swig Object of type 'tagLALSim...
#     SpinTaylorT4GeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     SpinTaylorT5 = 20
#     SpinTaylorT5Fourier = 88
#     SpinTaylorT5FourierGeneratorTemplate = <Swig Object of type 'tagLALSim...
#     SpinTaylorT5GeneratorTemplate = <Swig Object of type 'tagLALSimInspira...
#     TEOBResumS = 102
#     TEOBResumSGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralG...
#     TEOBResum_ROM = 41
#     TEOBResum_ROMGeneratorTemplate = <Swig Object of type 'tagLALSimInspir...
#     THIRTYFIVE_OVER_128 = 0.2734375
#     THREE_OVER_16 = 0.1875
#     THREE_OVER_EIGHT = 0.375
#     TaylorEt = 83
#     TaylorEtGeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     TaylorF1 = 3
#     TaylorF2 = 5
#     TaylorF2Ecc = 6
#     TaylorF2EccGeneratorTemplate = <Swig Object of type 'tagLALSimInspiral...
#     TaylorF2GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     TaylorF2NLTides = 7
#     TaylorF2NLTidesGeneratorTemplate = <Swig Object of type 'tagLALSimInsp...
#     TaylorF2RedSpin = 9
#     TaylorF2RedSpinGeneratorTemplate = <Swig Object of type 'tagLALSimInsp...
#     TaylorF2RedSpinTidal = 10
#     TaylorF2RedSpinTidalGeneratorTemplate = <Swig Object of type 'tagLALSi...
#     TaylorN = 86
#     TaylorR2F4 = 8
#     TaylorR2F4GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralG...
#     TaylorT1 = 0
#     TaylorT1GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     TaylorT2 = 1
#     TaylorT2GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     TaylorT3 = 2
#     TaylorT3GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     TaylorT4 = 84
#     TaylorT4GeneratorTemplate = <Swig Object of type 'tagLALSimInspiralGen...
#     fEOBNRv2HMRD = 6
#     fEOBNRv2RD = 5
#     fIMRPhenomAFinal = 1
#     fIMRPhenomBFinal = 2
#     fIMRPhenomCFinal = 3
#     fIMRPhenomDPeak = 4
#     fSEOBNRv1Peak = 7
#     fSEOBNRv1RD = 8
#     fSEOBNRv2Peak = 9
#     fSEOBNRv2RD = 10
#     fSEOBNRv4Peak = 11
#     fSEOBNRv4RD = 12
#     fSEOBNRv5Peak = 14
#     fSEOBNRv5RD = 15
#     fSchwarzISCO = 0
#     fTEOBResumSFinal = 13
#     globalvar = <Swig global variables>
#     k00 = -5.977230835551017
#     k01 = 3.39221
#     k02 = 4.48865
#     k03 = -5.77101
#     k04 = -13.0459
#     k10 = 35.1278
#     k11 = -72.9336
#     k12 = -86.0036
#     k13 = 93.7371
#     k14 = 200.975
#     k20 = -146.822
#     k21 = 387.184
#     k22 = 447.009
#     k23 = -467.383
#     k24 = -884.339
#     k30 = 223.911
#     k31 = -648.502
#     k32 = -697.177
#     k33 = 753.738
#     k34 = 1166.89
#     mSQRT_10_OVER_32 = -0.09882117688026186
#     mSQRT_15_OVER_32 = -0.12103072956898178
#     mSQRT_2_OVER_64 = -0.02209708691207961
#     mSQRT_6_OVER_32 = -0.07654655446197431
#     p0coeff = 0.04826
#     p1coeff = 0.01559
#     p2coeff = 0.00485
#     pSEOBNRv4HM_PA = 109
#     pSEOBNRv4HM_PAGeneratorTemplate = <Swig Object of type 'tagLALSimInspi...
#     s4coeff = -0.1229
#     s4v2coeff = -0.27506210736300474
#     s5coeff = 0.4537
#     s5v2coeff = -0.3264724801557159
#     s6coeff = -0.7835007857591175
#     s7coeff = 1.2657111864932808
#     s8coeff = -2.6081232221537394
#     s9coeff = 2.763032781169752
#     swig_version = 262657
#     t0coeff = -2.8904
#     t0v2coeff = -2.649826989941522
#     t2coeff = -3.5171
#     t2v2coeff = -3.850983155206041
#     t3coeff = 2.5763
#     t3v2coeff = 3.910637513328723
#
# VERSION
#     6.0.0
#
# FILE
#     /home/darkknight/anaconda3/envs/geotgr/lib/python3.10/site-packages/lalsimulation/__init__.py
